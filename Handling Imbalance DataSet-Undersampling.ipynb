# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn
import scipy
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 14, 8
# Out:
# C:\Users\Shihab Uddin\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
pd.pandas.set_option('display.max_columns',None)

# %%
# path = r"‪F:\Faurd Detection\creditcard.csv"
data = pd.read_csv('creditcard.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
columns = data.columns.tolist()

# %%
x = data[columns[:-1]]
y = data[columns[-1]]

# %%
x.shape,y.shape
# Out:
# ((284807, 30), (284807,))

# %% [markdown]
# ### Exploratory Data Analysis

# %%
count_values = pd.value_counts(data['Class'])

# %%
count_values
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
LABELS=['Normal','Farud']
count_values.plot(kind='bar',rot=0)
plt.title("Class Distribution")
plt.xticks(range(2),LABELS)
plt.xlabel("Frequence")
plt.ylabel("CLass")
# Out:
# Text(0, 0.5, 'CLass')

# %%
from imblearn.under_sampling import NearMiss

# %%
# !pip install imblearn

# %%
nm = NearMiss()
x_res,y_res = nm.fit_sample(x,y)

# %%
x_res.shape,y_res.shape
# Out:
# ((984, 30), (984,))

# %%
from collections import Counter
print('Original dataset shape {}'.format(Counter(y)))
print('Resampled dataset shape {}'.format(Counter(y_res)))
# Out:
# Original dataset shape Counter({0: 284315, 1: 492})
# Resampled dataset shape Counter({0: 492, 1: 492})

# %%
x_res
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 0     76866.0  1.257227  0.408096  0.319266  0.685011 -0.302937 -1.052552
# 1     76868.0  1.254775  0.375340  0.311959  0.691077 -0.343494 -1.065252
# 2     76870.0 -1.050697  1.500753  0.846326 -0.282956  0.059866 -0.561182
# 3     76866.0  1.245537  0.419648  0.312943  1.111459 -0.205612 -0.950912
# 4     76870.0  1.261137  0.304662  0.527018  0.612765 -0.411488 -0.972770
# ..        ...       ...       ...       ...       ...       ...       ...
# 979  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 980  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 981  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 982  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 983  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#            V7        V8        V9       V10       V11       V12       V13  \
# ...

# %%
afterUnderSampling = np.concatenate(x_res,y_res])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-80aa6f8c3b98> in <module>
# ----> 1 afterUnderSampling = np.concatenate([x_res,y_res])
#
# ValueError: all the input arrays must have same number of dimensions

# %%
x_res['Class'] = y_res

# %%
newData = x_res

# %%
newData
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 0     76866.0  1.257227  0.408096  0.319266  0.685011 -0.302937 -1.052552
# 1     76868.0  1.254775  0.375340  0.311959  0.691077 -0.343494 -1.065252
# 2     76870.0 -1.050697  1.500753  0.846326 -0.282956  0.059866 -0.561182
# 3     76866.0  1.245537  0.419648  0.312943  1.111459 -0.205612 -0.950912
# 4     76870.0  1.261137  0.304662  0.527018  0.612765 -0.411488 -0.972770
# ..        ...       ...       ...       ...       ...       ...       ...
# 979  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 980  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 981  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 982  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 983  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#            V7        V8        V9       V10       V11       V12       V13  \
# ...

# %%
afterUnderSampling
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-418c5c03fb44> in <module>
# ----> 1 afterUnderSampling
#
# NameError: name 'afterUnderSampling' is not defined

# %%
under_sample = data.loc[afterUnderSampling]

# %%
under_sample_count = pd.value_counts(newData['Class'])

# %%
under_sample_count
# Out:
# 1    492
# 0    492
# Name: Class, dtype: int64

# %%
LABELS=['Normal','Farud']
under_sample_count.plot(kind='bar',rot=0)
plt.title("Class Distribution")
plt.xticks(range(2),LABELS)
plt.xlabel("Frequence")
plt.ylabel("CLass")
# Out:
# Text(0, 0.5, 'CLass')
